# %% [markdown]
# # MLflow intro
#
# ### What to track?
# * Source code
# * Environment
# * Data
# * Model
# * Hyperparameters
# * Metrics
#
# ### What does MLflow do?
# A python package that could do tracking, models, model registry, projects.
#
# ### Installing MLflow
#
# pip: `pip install mlflow`
#
# conda: `conda install -c conda-forge mlflow`
#
# To run the MLflow UI locally we use the command, make sure this command is running from where the db is located:
#
# ```
# mlflow ui --backend-store-uri sqlite:///mlflow.db --port 5004
# ```
#
# Setup MLflow experiment:
#
# Import mlflow in notebook, set the database address and experiment name.

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc_taxis")
# Out:
# <Experiment: artifact_location='/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/00-my-work/mlruns/1', creation_time=1716360482562, experiment_id='1', last_update_time=1716360482562, lifecycle_stage='active', name='nyc_taxis', tags={}>

# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error
import pickle
import os

# %%
data_2401_path = "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-01.parquet"
data_2402_path = "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-02.parquet"

# %%
def read_dataframe(path):
    df = pd.read_parquet(path)
    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df['duration'] = df['duration'].apply(lambda x: x.total_seconds()/60)
    df = df[(df['duration'] > 1.0) & (df['duration'] < 60.0)]
    categorical = ['PULocationID','DOLocationID']
    df[categorical] = df[categorical].astype(str)
    return df

# %%
df_train = read_dataframe(data_2401_path)
df_val = read_dataframe(data_2402_path)

# %%
df_train['PU_DOLocationID'] = df_train['PULocationID']+"_"+df_train['DOLocationID']
df_val['PU_DOLocationID'] = df_val['PULocationID']+"_"+df_val['DOLocationID']

# %%
categorical = ['PULocationID','DOLocationID','PU_DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical+numerical].to_dict(orient="records")
x_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical+numerical].to_dict(orient="records")
x_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %% [markdown]
# # Track model run
#
# ```
# mlflow.{model}.autolog() ## make sure this is before mlflow.start_run()
# with mlflow.start_run() as run:
# 	# .... modeling....
#
# 	mlflow.set_tag('tag_name', 'tag_value')
# 	mlflow.log_param('param_name', param_obj) or mlflow.log_params(parm_obj)
# 	mlflow.sklearn.log_model(moldel_obj, artifact_path = 'path')
# 	mlflow.log_metric('metric_name', metric_obj)
# 	mlflow.log_artifact(artifact_obj or local_artifact_path, artifact_path)
#
# mlflow.stop_run() ## not necessary if using `with mlflow.start_run() as run:`
# ```

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_val)

mean_squared_error(y_val,y_pred,squared=False)
# Out:
# /opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 5.919781845355132

# %%
import os
# Create the pick file first
# Define the base directory where you want to save the model
base_dir = "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/00-my-work/wk2/models"
model_filename = "lin_reg.bin"
model_path = os.path.join(base_dir, model_filename)

# Ensure the directory exists, create if it does not
os.makedirs(base_dir, exist_ok=True)

# Save the model (assuming `lr` is your model variable)
with open(model_path, 'wb') as f:
    pickle.dump(lr, f)

# %%
with mlflow.start_run():
    mlflow.set_tag("developer", "yihan")
    mlflow.log_param("train-data-path", "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-01.parquet")
    mlflow.log_param("val-data-path", "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-02.parquet")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)

    lr = Lasso(alpha=alpha)
    lr.fit(x_train,y_train)
    
    y_pred = lr.predict(x_val)
    
    rmse = mean_squared_error(y_val,y_pred,squared=False) 
    mlflow.log_metric("rmse",rmse)
    mlflow.end_run()
    
    # save the model
    mlflow.log_artifact(local_path=model_path, artifact_path="models_pickle")
# Out:
# /opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# !ls
# Out:
# mlflow.db                preprocessor             wk2_notes.ipynb
# mlruns                   wk2_homework.ipynb
# models                   wk2_model_registry.ipynb

# %%
lr = Ridge(alpha=0.01)
lr.fit(x_train,y_train)

y_pred = lr.predict(x_val)

mean_squared_error(y_val,y_pred,squared=False)

# %% [markdown]
# ### Track model run with XGBoost
#
# ```
# mlflow.{model}.autolog() ## make sure this is before mlflow.start_run()
# with mlflow.start_run() as run:
# 	# .... modeling....
#
# 	mlflow.set_tag('tag_name', 'tag_value')
# 	mlflow.log_param('param_name', param_obj) or mlflow.log_params(parm_obj)
# 	mlflow.log_model(moldel_obj, artifact_path = 'path')
# 	mlflow.log_metric('metric_name', metric_obj)
# 	mlflow.log_artifact(artifact_obj or local_artifact_path, artifact_path)
#
# mlflow.stop_run() ## not necessary if using `with mlflow.start_run() as run:`
# ```

# %%
import xgboost as xgb

# bayesian methods to find the best set of hyperparameters, like optuna, ray tune(more comprehensive).

# fmin -> find minimal output from passed in values
# tpe  -> control the logic
# hp   -> control the search space
# STATUS_OK -> send signal at end of the run to tell the lib about the status
# trails -> track info of each run
# scope --> define integer range
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials 
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(x_train, label=y_train)
valid = xgb.DMatrix(x_val, label=y_val)

# %%
def objective(params):
    
    with mlflow.start_run():
        mlflow.set_tag('model', 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,"validation")],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared=False) 
        mlflow.log_metric("rmse",rmse)
        
    return {'loss': rmse, 'status': STATUS_OK}

# %%
# Define the range we want the hyperopt to find
search_space = {
    # depth of trees, quniform returns real numbers, scope.int converts to an int as max_depth needs an int
    "max_depth": scope.int(hp.quniform("max_depth",4, 100, 1)),
    # range: exp(-3), exp(0) -> [0.05, 1]
    "learning_rate": hp.loguniform("learning_rate", -3, 0),
    "reg_alpha": hp.loguniform('reg_alpha', -5, -1),
    "reg_lambda": hp.loguniform('reg_lambda', -6, -1),
    "min_child_weight": hp.loguniform('min_child_weight', -1, 3),
    "objective":"reg:linear",
    "seed":42,
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)

# %% [markdown]
# # Save model

# %% [markdown]
# ## Autologging
#
# Instead of logging the parameters by "Hand" by specifiying the logged parameters and passing them. We may use the Autologging feature in MLflow. There are two ways to use Autologging; First by enabling it globally in the code/Notebook using
# ```python
# mlflow.autolog()
# ```
#
# or by enabling the framework-specific autologger; ex with XGBoost:
#
# ```python
# mlflow.xgboost.autolog()
# ```
# Both must be done before running the experiments.
#
# The autologger then not only stores the model parameters for ease of use, it also stores other files inside the `model` (can be specified) folder inside our experiment artifact folder, these files include:
# + `conda.yaml` and `requirements.txt`: Files which define the current envrionment for use with either `conda` or `pip` respectively
# + `MLmodel` an internal MLflow file for organization
# + Other framework-specific files such as the model itself

# %%
mlflow.xgboost.autolog() # ensure that mlflow.xgboost.autolog() is called before any DMatrix objects are instantiated

params = {
        "learning_rate":0.05962727037069885,
        "max_depth":8,
        "min_child_weight": 1.6262090424037392,
        "objective": "reg:linear",
        "reg_alpha": 0.21113459659178727,
        "reg_lambda": 0.24977063291390747,
        "seed": 42}

train = xgb.DMatrix(x_train, label=y_train)
valid = xgb.DMatrix(x_val, label=y_val)
booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,"validation")],
            early_stopping_rounds=50
        )

prep_path = "models/preprocessor.b"
os.makedirs(os.path.dirname(prep_path), exist_ok=True)
with open(prep_path, 'wb') as file:
    pickle.dump(dv, file)
mlflow.log_artifact(prep_path, artifact_path = "preprocessor")
mlflow.xgboost.log_model(booster, artifact_path = "models_mlflow")
# Out:
# [0]	validation-rmse:8.75440
# [1]	validation-rmse:8.44120
# [2]	validation-rmse:8.15312
# [3]	validation-rmse:7.88895
# [4]	validation-rmse:7.64594
# [5]	validation-rmse:7.42486
# [6]	validation-rmse:7.22222
# [7]	validation-rmse:7.03797
# [8]	validation-rmse:6.87173
# [9]	validation-rmse:6.71989
# [10]	validation-rmse:6.58330
# [11]	validation-rmse:6.45792
# [12]	validation-rmse:6.34404
# [13]	validation-rmse:6.24138
# [14]	validation-rmse:6.14943
# /opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/xgboost/core.py:160: UserWarning: [12:52:55] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_b6b50u1t0e/croot/xgboost-split_1713972723244/work/cpp_src/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [15]	validation-rmse:6.06460
# [16]	validation-rmse:5.98775
# [17]	validation-rmse:5.91877
# [18]	validation-rmse:5.85717
# [19]	validation-rmse:5.80083
# [20]	validation-rmse:5.74932
# [21]	validation-rmse:5.70417
# [22]	validation-rmse:5.66419
# [23]	validation-rmse:5.62669
# [24]	validation-rmse:5.59157
# [25]	validation-rmse:5.56037
# [26]	validation-rmse:5.53387
# [27]	validation-rmse:5.50760
# [28]	validation-rmse:5.48418
# [29]	validation-rmse:5.46260
# [30]	validation-rmse:5.44421
# [31]	validation-rmse:5.42660
# [32]	validation-rmse:5.41038
# [33]	validation-rmse:5.39503
# [34]	validation-rmse:5.38172
# [35]	validation-rmse:5.37006
# [36]	validation-rmse:5.35918
# [37]	validation-rmse:5.34890
# [38]	validation-rmse:5.33952
# [39]	validation-rmse:5.33033
# [40]	validation-rmse:5.32135
# [41]	validation-rmse:5.31492
# [42]	validation-rmse:5.30652
# [43]	validation-rmse:5.29838
# [44]	validation-rmse:5.29253
# [45]	validation-rmse:5.28650
# [46]	validation-rmse:5.28110
# [47]	validation-rmse:5.27610
# [48]	validation-rmse:5.27167
# [49]	validation-rmse:5.26756
# [50]	validation-rmse:5.26289
# [51]	validation-rmse:5.25748
# [52]	validation-rmse:5.25381
# [53]	validation-rmse:5.25062
# [54]	validation-rmse:5.24660
# [55]	validation-rmse:5.24370
# [56]	validation-rmse:5.24108
# [57]	validation-rmse:5.23790
# [58]	validation-rmse:5.23536
# [59]	validation-rmse:5.23330
# [60]	validation-rmse:5.23045
# [61]	validation-rmse:5.22866
# [62]	validation-rmse:5.22570
# [63]	validation-rmse:5.22450
# [64]	validation-rmse:5.22250
# [65]	validation-rmse:5.22112
# [66]	validation-rmse:5.21866
# [67]	validation-rmse:5.21707
# [68]	validation-rmse:5.21458
# [69]	validation-rmse:5.21286
# [70]	validation-rmse:5.21115
# [71]	validation-rmse:5.20989
# [72]	validation-rmse:5.20715
# [73]	validation-rmse:5.20601
# [74]	validation-rmse:5.20531
# [75]	validation-rmse:5.20368
# [76]	validation-rmse:5.20193
# [77]	validation-rmse:5.20084
# [78]	validation-rmse:5.19985
# [79]	validation-rmse:5.19898
# [80]	validation-rmse:5.19755
# [81]	validation-rmse:5.19664
# [82]	validation-rmse:5.19480
# [83]	validation-rmse:5.19430
# [84]	validation-rmse:5.19246
# [85]	validation-rmse:5.19199
# [86]	validation-rmse:5.19046
# [87]	validation-rmse:5.18975
# [88]	validation-rmse:5.18776
# [89]	validation-rmse:5.18682
# [90]	validation-rmse:5.18507
# [91]	validation-rmse:5.18454
# [92]	validation-rmse:5.18350
# [93]	validation-rmse:5.18269
# [94]	validation-rmse:5.18198
# [95]	validation-rmse:5.17957
# [96]	validation-rmse:5.17907
# [97]	validation-rmse:5.17832
# [98]	validation-rmse:5.17755
# [99]	validation-rmse:5.17660
# [100]	validation-rmse:5.17614
# [101]	validation-rmse:5.17569
# [102]	validation-rmse:5.17348
# [103]	validation-rmse:5.17240
# [104]	validation-rmse:5.17194
# [105]	validation-rmse:5.17106
# [106]	validation-rmse:5.17061
# [107]	validation-rmse:5.17041
# [108]	validation-rmse:5.16970
# [109]	validation-rmse:5.16917
# [110]	validation-rmse:5.16832
# [111]	validation-rmse:5.16805
# [112]	validation-rmse:5.16744
# [113]	validation-rmse:5.16570
# [114]	validation-rmse:5.16503
# [115]	validation-rmse:5.16395
# [116]	validation-rmse:5.16272
# [117]	validation-rmse:5.16190
# [118]	validation-rmse:5.16133
# [119]	validation-rmse:5.16074
# [120]	validation-rmse:5.16037
# [121]	validation-rmse:5.15978
# [122]	validation-rmse:5.15934
# [123]	validation-rmse:5.15902
# [124]	validation-rmse:5.15769
# [125]	validation-rmse:5.15738
# [126]	validation-rmse:5.15542
# [127]	validation-rmse:5.15462
# [128]	validation-rmse:5.15347
# [129]	validation-rmse:5.15322
# [130]	validation-rmse:5.15303
# [131]	validation-rmse:5.15217
# [132]	validation-rmse:5.15206
# [133]	validation-rmse:5.15084
# [134]	validation-rmse:5.15024
# [135]	validation-rmse:5.15005
# [136]	validation-rmse:5.14969
# [137]	validation-rmse:5.14867
# [138]	validation-rmse:5.14857
# [139]	validation-rmse:5.14780
# [140]	validation-rmse:5.14757
# [141]	validation-rmse:5.14684
# [142]	validation-rmse:5.14646
# [143]	validation-rmse:5.14610
# [144]	validation-rmse:5.14591
# [145]	validation-rmse:5.14554
# [146]	validation-rmse:5.14510
# [147]	validation-rmse:5.14413
# [148]	validation-rmse:5.14263
# [149]	validation-rmse:5.14236
# [150]	validation-rmse:5.14095
# [151]	validation-rmse:5.14073
# [152]	validation-rmse:5.13979
# [153]	validation-rmse:5.13924
# [154]	validation-rmse:5.13836
# [155]	validation-rmse:5.13758
# [156]	validation-rmse:5.13664
# [157]	validation-rmse:5.13641
# [158]	validation-rmse:5.13611
# [159]	validation-rmse:5.13559
# [160]	validation-rmse:5.13506
# [161]	validation-rmse:5.13412
# [162]	validation-rmse:5.13360
# [163]	validation-rmse:5.13336
# [164]	validation-rmse:5.13319
# [165]	validation-rmse:5.13285
# [166]	validation-rmse:5.13247
# [167]	validation-rmse:5.13200
# [168]	validation-rmse:5.13138
# [169]	validation-rmse:5.13061
# [170]	validation-rmse:5.12988
# [171]	validation-rmse:5.12852
# [172]	validation-rmse:5.12833
# [173]	validation-rmse:5.12805
# [174]	validation-rmse:5.12804
# [175]	validation-rmse:5.12736
# [176]	validation-rmse:5.12702
# [177]	validation-rmse:5.12643
# [178]	validation-rmse:5.12586
# [179]	validation-rmse:5.12561
# [180]	validation-rmse:5.12471
# [181]	validation-rmse:5.12421
# [182]	validation-rmse:5.12411
# [183]	validation-rmse:5.12322
# [184]	validation-rmse:5.12287
# [185]	validation-rmse:5.12283
# [186]	validation-rmse:5.12277
# [187]	validation-rmse:5.12230
# [188]	validation-rmse:5.12212
# [189]	validation-rmse:5.12175
# [190]	validation-rmse:5.12098
# [191]	validation-rmse:5.12080
# [192]	validation-rmse:5.12045
# [193]	validation-rmse:5.11986
# [194]	validation-rmse:5.11969
# [195]	validation-rmse:5.11943
# [196]	validation-rmse:5.11871
# [197]	validation-rmse:5.11783
# [198]	validation-rmse:5.11791
# [199]	validation-rmse:5.11668
# [200]	validation-rmse:5.11626
# [201]	validation-rmse:5.11590
# [202]	validation-rmse:5.11529
# [203]	validation-rmse:5.11418
# [204]	validation-rmse:5.11374
# [205]	validation-rmse:5.11339
# [206]	validation-rmse:5.11292
# [207]	validation-rmse:5.11259
# [208]	validation-rmse:5.11232
# [209]	validation-rmse:5.11224
# [210]	validation-rmse:5.11220
# [211]	validation-rmse:5.11211
# [212]	validation-rmse:5.11170
# [213]	validation-rmse:5.11158
# [214]	validation-rmse:5.11119
# [215]	validation-rmse:5.11100
# [216]	validation-rmse:5.11076
# [217]	validation-rmse:5.11029
# [218]	validation-rmse:5.10958
# [219]	validation-rmse:5.10937
# [220]	validation-rmse:5.10890
# [221]	validation-rmse:5.10867
# [222]	validation-rmse:5.10798
# [223]	validation-rmse:5.10785
# [224]	validation-rmse:5.10738
# [225]	validation-rmse:5.10698
# [226]	validation-rmse:5.10623
# [227]	validation-rmse:5.10619
# [228]	validation-rmse:5.10586
# [229]	validation-rmse:5.10524
# [230]	validation-rmse:5.10502
# [231]	validation-rmse:5.10466
# [232]	validation-rmse:5.10408
# [233]	validation-rmse:5.10334
# [234]	validation-rmse:5.10322
# [235]	validation-rmse:5.10203
# [236]	validation-rmse:5.10184
# [237]	validation-rmse:5.10143
# [238]	validation-rmse:5.10134
# [239]	validation-rmse:5.10121
# [240]	validation-rmse:5.10084
# [241]	validation-rmse:5.10067
# [242]	validation-rmse:5.10055
# [243]	validation-rmse:5.10046
# [244]	validation-rmse:5.10022
# [245]	validation-rmse:5.09994
# [246]	validation-rmse:5.09959
# [247]	validation-rmse:5.09938
# [248]	validation-rmse:5.09918
# [249]	validation-rmse:5.09858
# [250]	validation-rmse:5.09838
# [251]	validation-rmse:5.09831
# [252]	validation-rmse:5.09821
# [253]	validation-rmse:5.09754
# [254]	validation-rmse:5.09716
# [255]	validation-rmse:5.09679
# [256]	validation-rmse:5.09607
# [257]	validation-rmse:5.09544
# [258]	validation-rmse:5.09486
# [259]	validation-rmse:5.09477
# [260]	validation-rmse:5.09446
# [261]	validation-rmse:5.09423
# [262]	validation-rmse:5.09381
# [263]	validation-rmse:5.09305
# [264]	validation-rmse:5.09277
# [265]	validation-rmse:5.09232
# [266]	validation-rmse:5.09221
# [267]	validation-rmse:5.09207
# [268]	validation-rmse:5.09184
# [269]	validation-rmse:5.09164
# [270]	validation-rmse:5.09162
# [271]	validation-rmse:5.09128
# [272]	validation-rmse:5.09083
# [273]	validation-rmse:5.09039
# [274]	validation-rmse:5.09037
# [275]	validation-rmse:5.09042
# [276]	validation-rmse:5.09025
# [277]	validation-rmse:5.08987
# [278]	validation-rmse:5.08984
# [279]	validation-rmse:5.08896
# [280]	validation-rmse:5.08830
# [281]	validation-rmse:5.08822
# [282]	validation-rmse:5.08748
# [283]	validation-rmse:5.08723
# [284]	validation-rmse:5.08694
# [285]	validation-rmse:5.08678
# [286]	validation-rmse:5.08654
# [287]	validation-rmse:5.08627
# [288]	validation-rmse:5.08595
# [289]	validation-rmse:5.08529
# [290]	validation-rmse:5.08527
# [291]	validation-rmse:5.08474
# [292]	validation-rmse:5.08463
# [293]	validation-rmse:5.08429
# [294]	validation-rmse:5.08409
# [295]	validation-rmse:5.08380
# [296]	validation-rmse:5.08371
# [297]	validation-rmse:5.08341
# [298]	validation-rmse:5.08323
# [299]	validation-rmse:5.08264
# [300]	validation-rmse:5.08231
# [301]	validation-rmse:5.08196
# [302]	validation-rmse:5.08180
# [303]	validation-rmse:5.08153
# [304]	validation-rmse:5.08108
# [305]	validation-rmse:5.08088
# [306]	validation-rmse:5.08009
# [307]	validation-rmse:5.07947
# [308]	validation-rmse:5.07938
# [309]	validation-rmse:5.07896
# [310]	validation-rmse:5.07879
# [311]	validation-rmse:5.07864
# [312]	validation-rmse:5.07846
# [313]	validation-rmse:5.07840
# [314]	validation-rmse:5.07843
# [315]	validation-rmse:5.07828
# [316]	validation-rmse:5.07812
# [317]	validation-rmse:5.07795
# [318]	validation-rmse:5.07771
# [319]	validation-rmse:5.07770
# [320]	validation-rmse:5.07757
# [321]	validation-rmse:5.07728
# [322]	validation-rmse:5.07677
# [323]	validation-rmse:5.07650
# [324]	validation-rmse:5.07655
# [325]	validation-rmse:5.07623
# [326]	validation-rmse:5.07602
# [327]	validation-rmse:5.07600
# [328]	validation-rmse:5.07569
# [329]	validation-rmse:5.07560
# [330]	validation-rmse:5.07560
# [331]	validation-rmse:5.07528
# [332]	validation-rmse:5.07487
# [333]	validation-rmse:5.07482
# [334]	validation-rmse:5.07412
# [335]	validation-rmse:5.07406
# [336]	validation-rmse:5.07403
# [337]	validation-rmse:5.07386
# [338]	validation-rmse:5.07392
# [339]	validation-rmse:5.07363
# [340]	validation-rmse:5.07344
# [341]	validation-rmse:5.07339
# [342]	validation-rmse:5.07320
# [343]	validation-rmse:5.07294
# [344]	validation-rmse:5.07292
# [345]	validation-rmse:5.07285
# [346]	validation-rmse:5.07268
# [347]	validation-rmse:5.07242
# [348]	validation-rmse:5.07246
# [349]	validation-rmse:5.07247
# [350]	validation-rmse:5.07218
# [351]	validation-rmse:5.07223
# [352]	validation-rmse:5.07191
# [353]	validation-rmse:5.07167
# [354]	validation-rmse:5.07173
# [355]	validation-rmse:5.07148
# [356]	validation-rmse:5.07126
# [357]	validation-rmse:5.07068
# [358]	validation-rmse:5.06995
# [359]	validation-rmse:5.06996
# [360]	validation-rmse:5.06979
# [361]	validation-rmse:5.06964
# [362]	validation-rmse:5.06960
# [363]	validation-rmse:5.06941
# [364]	validation-rmse:5.06919
# [365]	validation-rmse:5.06907
# [366]	validation-rmse:5.06885
# [367]	validation-rmse:5.06860
# [368]	validation-rmse:5.06817
# [369]	validation-rmse:5.06797
# [370]	validation-rmse:5.06706
# [371]	validation-rmse:5.06622
# [372]	validation-rmse:5.06623
# [373]	validation-rmse:5.06577
# [374]	validation-rmse:5.06551
# [375]	validation-rmse:5.06570
# [376]	validation-rmse:5.06564
# [377]	validation-rmse:5.06549
# [378]	validation-rmse:5.06466
# [379]	validation-rmse:5.06453
# [380]	validation-rmse:5.06436
# [381]	validation-rmse:5.06408
# [382]	validation-rmse:5.06407
# [383]	validation-rmse:5.06377
# [384]	validation-rmse:5.06371
# [385]	validation-rmse:5.06358
# [386]	validation-rmse:5.06341
# [387]	validation-rmse:5.06339
# [388]	validation-rmse:5.06318
# [389]	validation-rmse:5.06316
# [390]	validation-rmse:5.06256
# [391]	validation-rmse:5.06259
# [392]	validation-rmse:5.06196
# [393]	validation-rmse:5.06185
# [394]	validation-rmse:5.06171
# [395]	validation-rmse:5.06146
# [396]	validation-rmse:5.06157
# [397]	validation-rmse:5.06151
# [398]	validation-rmse:5.06144
# [399]	validation-rmse:5.06141
# [400]	validation-rmse:5.06137
# [401]	validation-rmse:5.06076
# [402]	validation-rmse:5.06064
# [403]	validation-rmse:5.06041
# [404]	validation-rmse:5.06026
# [405]	validation-rmse:5.06009
# [406]	validation-rmse:5.05981
# [407]	validation-rmse:5.05925
# [408]	validation-rmse:5.05889
# [409]	validation-rmse:5.05874
# [410]	validation-rmse:5.05865
# [411]	validation-rmse:5.05858
# [412]	validation-rmse:5.05850
# [413]	validation-rmse:5.05860
# [414]	validation-rmse:5.05826
# [415]	validation-rmse:5.05774
# [416]	validation-rmse:5.05720
# [417]	validation-rmse:5.05722
# [418]	validation-rmse:5.05678
# [419]	validation-rmse:5.05672
# [420]	validation-rmse:5.05630
# [421]	validation-rmse:5.05600
# [422]	validation-rmse:5.05595
# [423]	validation-rmse:5.05586
# [424]	validation-rmse:5.05567
# [425]	validation-rmse:5.05561
# [426]	validation-rmse:5.05512
# [427]	validation-rmse:5.05459
# [428]	validation-rmse:5.05462
# [429]	validation-rmse:5.05424
# [430]	validation-rmse:5.05414
# [431]	validation-rmse:5.05398
# [432]	validation-rmse:5.05359
# [433]	validation-rmse:5.05344
# [434]	validation-rmse:5.05358
# [435]	validation-rmse:5.05350
# [436]	validation-rmse:5.05332
# [437]	validation-rmse:5.05308
# [438]	validation-rmse:5.05270
# [439]	validation-rmse:5.05242
# [440]	validation-rmse:5.05194
# [441]	validation-rmse:5.05190
# [442]	validation-rmse:5.05181
# [443]	validation-rmse:5.05187
# [444]	validation-rmse:5.05131
# [445]	validation-rmse:5.05122
# [446]	validation-rmse:5.05102
# [447]	validation-rmse:5.05100
# [448]	validation-rmse:5.05092
# [449]	validation-rmse:5.05079
# [450]	validation-rmse:5.05069
# [451]	validation-rmse:5.05059
# [452]	validation-rmse:5.05046
# [453]	validation-rmse:5.05044
# [454]	validation-rmse:5.05010
# [455]	validation-rmse:5.04982
# [456]	validation-rmse:5.04973
# [457]	validation-rmse:5.04968
# [458]	validation-rmse:5.04961
# [459]	validation-rmse:5.04919
# [460]	validation-rmse:5.04902
# [461]	validation-rmse:5.04887
# [462]	validation-rmse:5.04864
# [463]	validation-rmse:5.04834
# [464]	validation-rmse:5.04802
# [465]	validation-rmse:5.04776
# [466]	validation-rmse:5.04766
# [467]	validation-rmse:5.04751
# [468]	validation-rmse:5.04753
# [469]	validation-rmse:5.04697
# [470]	validation-rmse:5.04655
# [471]	validation-rmse:5.04653
# [472]	validation-rmse:5.04650
# [473]	validation-rmse:5.04649
# [474]	validation-rmse:5.04644
# [475]	validation-rmse:5.04644
# [476]	validation-rmse:5.04635
# [477]	validation-rmse:5.04616
# [478]	validation-rmse:5.04607
# [479]	validation-rmse:5.04595
# [480]	validation-rmse:5.04596
# [481]	validation-rmse:5.04584
# [482]	validation-rmse:5.04579
# [483]	validation-rmse:5.04555
# [484]	validation-rmse:5.04540
# [485]	validation-rmse:5.04548
# [486]	validation-rmse:5.04544
# [487]	validation-rmse:5.04513
# [488]	validation-rmse:5.04486
# [489]	validation-rmse:5.04453
# [490]	validation-rmse:5.04458
# [491]	validation-rmse:5.04440
# [492]	validation-rmse:5.04408
# [493]	validation-rmse:5.04408
# [494]	validation-rmse:5.04397
# [495]	validation-rmse:5.04354
# [496]	validation-rmse:5.04347
# [497]	validation-rmse:5.04260
# [498]	validation-rmse:5.04252
# [499]	validation-rmse:5.04250
# [500]	validation-rmse:5.04219
# [501]	validation-rmse:5.04209
# [502]	validation-rmse:5.04199
# [503]	validation-rmse:5.04192
# [504]	validation-rmse:5.04193
# [505]	validation-rmse:5.04191
# [506]	validation-rmse:5.04127
# [507]	validation-rmse:5.04111
# [508]	validation-rmse:5.04107
# [509]	validation-rmse:5.04086
# [510]	validation-rmse:5.04073
# [511]	validation-rmse:5.04079
# [512]	validation-rmse:5.04062
# [513]	validation-rmse:5.04055
# [514]	validation-rmse:5.04039
# [515]	validation-rmse:5.04016
# [516]	validation-rmse:5.04007
# [517]	validation-rmse:5.03996
# [518]	validation-rmse:5.03964
# [519]	validation-rmse:5.03949
# [520]	validation-rmse:5.03947
# [521]	validation-rmse:5.03922
# [522]	validation-rmse:5.03917
# [523]	validation-rmse:5.03912
# [524]	validation-rmse:5.03890
# [525]	validation-rmse:5.03873
# [526]	validation-rmse:5.03837
# [527]	validation-rmse:5.03833
# [528]	validation-rmse:5.03833
# [529]	validation-rmse:5.03799
# [530]	validation-rmse:5.03791
# [531]	validation-rmse:5.03807
# [532]	validation-rmse:5.03762
# [533]	validation-rmse:5.03707
# [534]	validation-rmse:5.03708
# [535]	validation-rmse:5.03655
# [536]	validation-rmse:5.03661
# [537]	validation-rmse:5.03650
# [538]	validation-rmse:5.03614
# [539]	validation-rmse:5.03585
# [540]	validation-rmse:5.03578
# [541]	validation-rmse:5.03546
# [542]	validation-rmse:5.03552
# [543]	validation-rmse:5.03547
# [544]	validation-rmse:5.03539
# [545]	validation-rmse:5.03527
# [546]	validation-rmse:5.03510
# [547]	validation-rmse:5.03506
# [548]	validation-rmse:5.03489
# [549]	validation-rmse:5.03485
# [550]	validation-rmse:5.03491
# [551]	validation-rmse:5.03445
# [552]	validation-rmse:5.03446
# [553]	validation-rmse:5.03412
# [554]	validation-rmse:5.03367
# [555]	validation-rmse:5.03366
# [556]	validation-rmse:5.03362
# [557]	validation-rmse:5.03365
# [558]	validation-rmse:5.03324
# [559]	validation-rmse:5.03302
# [560]	validation-rmse:5.03277
# [561]	validation-rmse:5.03245
# [562]	validation-rmse:5.03242
# [563]	validation-rmse:5.03230
# [564]	validation-rmse:5.03229
# [565]	validation-rmse:5.03241
# [566]	validation-rmse:5.03238
# [567]	validation-rmse:5.03227
# [568]	validation-rmse:5.03224
# [569]	validation-rmse:5.03213
# [570]	validation-rmse:5.03211
# [571]	validation-rmse:5.03201
# [572]	validation-rmse:5.03209
# [573]	validation-rmse:5.03206
# [574]	validation-rmse:5.03204
# [575]	validation-rmse:5.03197
# [576]	validation-rmse:5.03190
# [577]	validation-rmse:5.03177
# [578]	validation-rmse:5.03184
# [579]	validation-rmse:5.03188
# [580]	validation-rmse:5.03190
# [581]	validation-rmse:5.03181
# [582]	validation-rmse:5.03168
# [583]	validation-rmse:5.03156
# [584]	validation-rmse:5.03131
# [585]	validation-rmse:5.03137
# [586]	validation-rmse:5.03125
# [587]	validation-rmse:5.03115
# [588]	validation-rmse:5.03098
# [589]	validation-rmse:5.03112
# [590]	validation-rmse:5.03091
# [591]	validation-rmse:5.03072
# [592]	validation-rmse:5.03066
# [593]	validation-rmse:5.03043
# [594]	validation-rmse:5.03043
# [595]	validation-rmse:5.02984
# [596]	validation-rmse:5.02985
# [597]	validation-rmse:5.02988
# [598]	validation-rmse:5.02997
# [599]	validation-rmse:5.02985
# [600]	validation-rmse:5.02976
# [601]	validation-rmse:5.02984
# [602]	validation-rmse:5.02975
# [603]	validation-rmse:5.02968
# [604]	validation-rmse:5.02952
# [605]	validation-rmse:5.02931
# [606]	validation-rmse:5.02880
# [607]	validation-rmse:5.02868
# [608]	validation-rmse:5.02864
# [609]	validation-rmse:5.02859
# [610]	validation-rmse:5.02860
# [611]	validation-rmse:5.02860
# [612]	validation-rmse:5.02864
# [613]	validation-rmse:5.02825
# [614]	validation-rmse:5.02823
# [615]	validation-rmse:5.02802
# [616]	validation-rmse:5.02793
# [617]	validation-rmse:5.02737
# [618]	validation-rmse:5.02711
# [619]	validation-rmse:5.02711
# [620]	validation-rmse:5.02717
# [621]	validation-rmse:5.02708
# [622]	validation-rmse:5.02705
# [623]	validation-rmse:5.02661
# [624]	validation-rmse:5.02654
# [625]	validation-rmse:5.02650
# [626]	validation-rmse:5.02650
# [627]	validation-rmse:5.02633
# [628]	validation-rmse:5.02626
# [629]	validation-rmse:5.02612
# [630]	validation-rmse:5.02613
# [631]	validation-rmse:5.02611
# [632]	validation-rmse:5.02612
# [633]	validation-rmse:5.02584
# [634]	validation-rmse:5.02585
# [635]	validation-rmse:5.02585
# [636]	validation-rmse:5.02559
# [637]	validation-rmse:5.02548
# [638]	validation-rmse:5.02538
# [639]	validation-rmse:5.02530
# [640]	validation-rmse:5.02528
# [641]	validation-rmse:5.02481
# [642]	validation-rmse:5.02487
# [643]	validation-rmse:5.02485
# [644]	validation-rmse:5.02481
# [645]	validation-rmse:5.02465
# [646]	validation-rmse:5.02449
# [647]	validation-rmse:5.02451
# [648]	validation-rmse:5.02477
# [649]	validation-rmse:5.02470
# [650]	validation-rmse:5.02469
# [651]	validation-rmse:5.02482
# [652]	validation-rmse:5.02477
# [653]	validation-rmse:5.02479
# [654]	validation-rmse:5.02466
# [655]	validation-rmse:5.02458
# [656]	validation-rmse:5.02464
# [657]	validation-rmse:5.02462
# [658]	validation-rmse:5.02430
# [659]	validation-rmse:5.02403
# [660]	validation-rmse:5.02381
# [661]	validation-rmse:5.02376
# [662]	validation-rmse:5.02351
# [663]	validation-rmse:5.02348
# [664]	validation-rmse:5.02353
# [665]	validation-rmse:5.02348
# [666]	validation-rmse:5.02337
# [667]	validation-rmse:5.02330
# [668]	validation-rmse:5.02316
# [669]	validation-rmse:5.02311
# [670]	validation-rmse:5.02296
# [671]	validation-rmse:5.02289
# [672]	validation-rmse:5.02312
# [673]	validation-rmse:5.02302
# [674]	validation-rmse:5.02301
# [675]	validation-rmse:5.02290
# [676]	validation-rmse:5.02287
# [677]	validation-rmse:5.02309
# [678]	validation-rmse:5.02314
# [679]	validation-rmse:5.02313
# [680]	validation-rmse:5.02307
# [681]	validation-rmse:5.02268
# [682]	validation-rmse:5.02259
# [683]	validation-rmse:5.02258
# [684]	validation-rmse:5.02259
# [685]	validation-rmse:5.02203
# [686]	validation-rmse:5.02195
# [687]	validation-rmse:5.02161
# [688]	validation-rmse:5.02151
# [689]	validation-rmse:5.02145
# [690]	validation-rmse:5.02133
# [691]	validation-rmse:5.02122
# [692]	validation-rmse:5.02118
# [693]	validation-rmse:5.02117
# [694]	validation-rmse:5.02061
# [695]	validation-rmse:5.02029
# [696]	validation-rmse:5.02007
# [697]	validation-rmse:5.01970
# [698]	validation-rmse:5.01970
# [699]	validation-rmse:5.01964
# [700]	validation-rmse:5.01957
# [701]	validation-rmse:5.01942
# [702]	validation-rmse:5.01947
# [703]	validation-rmse:5.01949
# [704]	validation-rmse:5.01957
# [705]	validation-rmse:5.01965
# [706]	validation-rmse:5.01937
# [707]	validation-rmse:5.01934
# [708]	validation-rmse:5.01938
# [709]	validation-rmse:5.01936
# [710]	validation-rmse:5.01894
# [711]	validation-rmse:5.01918
# [712]	validation-rmse:5.01887
# [713]	validation-rmse:5.01874
# [714]	validation-rmse:5.01869
# [715]	validation-rmse:5.01871
# [716]	validation-rmse:5.01870
# [717]	validation-rmse:5.01866
# [718]	validation-rmse:5.01860
# [719]	validation-rmse:5.01854
# [720]	validation-rmse:5.01848
# [721]	validation-rmse:5.01842
# [722]	validation-rmse:5.01803
# [723]	validation-rmse:5.01770
# [724]	validation-rmse:5.01768
# [725]	validation-rmse:5.01740
# [726]	validation-rmse:5.01746
# [727]	validation-rmse:5.01750
# [728]	validation-rmse:5.01739
# [729]	validation-rmse:5.01727
# [730]	validation-rmse:5.01730
# [731]	validation-rmse:5.01736
# [732]	validation-rmse:5.01734
# [733]	validation-rmse:5.01725
# [734]	validation-rmse:5.01716
# [735]	validation-rmse:5.01703
# [736]	validation-rmse:5.01681
# [737]	validation-rmse:5.01685
# [738]	validation-rmse:5.01680
# [739]	validation-rmse:5.01680
# [740]	validation-rmse:5.01686
# [741]	validation-rmse:5.01700
# [742]	validation-rmse:5.01666
# [743]	validation-rmse:5.01641
# [744]	validation-rmse:5.01641
# [745]	validation-rmse:5.01626
# [746]	validation-rmse:5.01631
# [747]	validation-rmse:5.01630
# [748]	validation-rmse:5.01620
# [749]	validation-rmse:5.01613
# [750]	validation-rmse:5.01598
# [751]	validation-rmse:5.01577
# [752]	validation-rmse:5.01563
# [753]	validation-rmse:5.01558
# [754]	validation-rmse:5.01560
# [755]	validation-rmse:5.01557
# [756]	validation-rmse:5.01579
# [757]	validation-rmse:5.01579
# [758]	validation-rmse:5.01576
# [759]	validation-rmse:5.01544
# [760]	validation-rmse:5.01531
# [761]	validation-rmse:5.01526
# [762]	validation-rmse:5.01516
# [763]	validation-rmse:5.01517
# [764]	validation-rmse:5.01510
# [765]	validation-rmse:5.01513
# [766]	validation-rmse:5.01525
# [767]	validation-rmse:5.01497
# [768]	validation-rmse:5.01471
# [769]	validation-rmse:5.01476
# [770]	validation-rmse:5.01465
# [771]	validation-rmse:5.01471
# [772]	validation-rmse:5.01426
# [773]	validation-rmse:5.01414
# [774]	validation-rmse:5.01442
# [775]	validation-rmse:5.01438
# [776]	validation-rmse:5.01435
# [777]	validation-rmse:5.01442
# [778]	validation-rmse:5.01450
# [779]	validation-rmse:5.01448
# [780]	validation-rmse:5.01415
# [781]	validation-rmse:5.01404
# [782]	validation-rmse:5.01412
# [783]	validation-rmse:5.01411
# [784]	validation-rmse:5.01387
# [785]	validation-rmse:5.01372
# [786]	validation-rmse:5.01363
# [787]	validation-rmse:5.01356
# [788]	validation-rmse:5.01350
# [789]	validation-rmse:5.01300
# [790]	validation-rmse:5.01289
# [791]	validation-rmse:5.01265
# [792]	validation-rmse:5.01253
# [793]	validation-rmse:5.01238
# [794]	validation-rmse:5.01231
# [795]	validation-rmse:5.01229
# [796]	validation-rmse:5.01236
# [797]	validation-rmse:5.01243
# [798]	validation-rmse:5.01240
# [799]	validation-rmse:5.01244
# [800]	validation-rmse:5.01223
# [801]	validation-rmse:5.01214
# [802]	validation-rmse:5.01215
# [803]	validation-rmse:5.01211
# [804]	validation-rmse:5.01215
# [805]	validation-rmse:5.01216
# [806]	validation-rmse:5.01210
# [807]	validation-rmse:5.01207
# [808]	validation-rmse:5.01209
# [809]	validation-rmse:5.01202
# [810]	validation-rmse:5.01187
# [811]	validation-rmse:5.01176
# [812]	validation-rmse:5.01172
# [813]	validation-rmse:5.01183
# [814]	validation-rmse:5.01194
# [815]	validation-rmse:5.01187
# [816]	validation-rmse:5.01142
# [817]	validation-rmse:5.01144
# [818]	validation-rmse:5.01106
# [819]	validation-rmse:5.01106
# [820]	validation-rmse:5.01105
# [821]	validation-rmse:5.01099
# [822]	validation-rmse:5.01098
# [823]	validation-rmse:5.01085
# [824]	validation-rmse:5.01068
# [825]	validation-rmse:5.01063
# [826]	validation-rmse:5.01059
# [827]	validation-rmse:5.01068
# [828]	validation-rmse:5.01070
# [829]	validation-rmse:5.01021
# [830]	validation-rmse:5.01022
# [831]	validation-rmse:5.01037
# [832]	validation-rmse:5.01026
# [833]	validation-rmse:5.01013
# [834]	validation-rmse:5.00991
# [835]	validation-rmse:5.00980
# [836]	validation-rmse:5.00965
# [837]	validation-rmse:5.00968
# [838]	validation-rmse:5.00962
# [839]	validation-rmse:5.00958
# [840]	validation-rmse:5.00951
# [841]	validation-rmse:5.00962
# [842]	validation-rmse:5.00944
# [843]	validation-rmse:5.00935
# [844]	validation-rmse:5.00936
# [845]	validation-rmse:5.00933
# [846]	validation-rmse:5.00922
# [847]	validation-rmse:5.00898
# [848]	validation-rmse:5.00913
# [849]	validation-rmse:5.00917
# [850]	validation-rmse:5.00930
# [851]	validation-rmse:5.00909
# [852]	validation-rmse:5.00907
# [853]	validation-rmse:5.00902
# [854]	validation-rmse:5.00892
# [855]	validation-rmse:5.00898
# [856]	validation-rmse:5.00890
# [857]	validation-rmse:5.00884
# [858]	validation-rmse:5.00854
# [859]	validation-rmse:5.00847
# [860]	validation-rmse:5.00827
# [861]	validation-rmse:5.00822
# [862]	validation-rmse:5.00820
# [863]	validation-rmse:5.00803
# [864]	validation-rmse:5.00799
# [865]	validation-rmse:5.00793
# [866]	validation-rmse:5.00781
# [867]	validation-rmse:5.00788
# [868]	validation-rmse:5.00790
# [869]	validation-rmse:5.00795
# [870]	validation-rmse:5.00753
# [871]	validation-rmse:5.00751
# [872]	validation-rmse:5.00745
# [873]	validation-rmse:5.00738
# [874]	validation-rmse:5.00731
# [875]	validation-rmse:5.00723
# [876]	validation-rmse:5.00723
# [877]	validation-rmse:5.00723
# [878]	validation-rmse:5.00714
# [879]	validation-rmse:5.00719
# [880]	validation-rmse:5.00724
# [881]	validation-rmse:5.00721
# [882]	validation-rmse:5.00718
# [883]	validation-rmse:5.00698
# [884]	validation-rmse:5.00699
# [885]	validation-rmse:5.00703
# [886]	validation-rmse:5.00703
# [887]	validation-rmse:5.00693
# [888]	validation-rmse:5.00689
# [889]	validation-rmse:5.00678
# [890]	validation-rmse:5.00677
# [891]	validation-rmse:5.00672
# [892]	validation-rmse:5.00674
# [893]	validation-rmse:5.00672
# [894]	validation-rmse:5.00663
# [895]	validation-rmse:5.00659
# [896]	validation-rmse:5.00645
# [897]	validation-rmse:5.00640
# [898]	validation-rmse:5.00633
# [899]	validation-rmse:5.00643
# [900]	validation-rmse:5.00630
# [901]	validation-rmse:5.00615
# [902]	validation-rmse:5.00604
# [903]	validation-rmse:5.00616
# [904]	validation-rmse:5.00621
# [905]	validation-rmse:5.00618
# [906]	validation-rmse:5.00629
# [907]	validation-rmse:5.00622
# [908]	validation-rmse:5.00627
# [909]	validation-rmse:5.00632
# [910]	validation-rmse:5.00632
# [911]	validation-rmse:5.00617
# [912]	validation-rmse:5.00613
# [913]	validation-rmse:5.00610
# [914]	validation-rmse:5.00603
# [915]	validation-rmse:5.00599
# [916]	validation-rmse:5.00585
# [917]	validation-rmse:5.00586
# [918]	validation-rmse:5.00579
# [919]	validation-rmse:5.00562
# [920]	validation-rmse:5.00558
# [921]	validation-rmse:5.00555
# [922]	validation-rmse:5.00548
# [923]	validation-rmse:5.00546
# [924]	validation-rmse:5.00543
# [925]	validation-rmse:5.00535
# [926]	validation-rmse:5.00542
# [927]	validation-rmse:5.00544
# [928]	validation-rmse:5.00535
# [929]	validation-rmse:5.00542
# [930]	validation-rmse:5.00546
# [931]	validation-rmse:5.00539
# [932]	validation-rmse:5.00463
# [933]	validation-rmse:5.00463
# [934]	validation-rmse:5.00460
# [935]	validation-rmse:5.00460
# [936]	validation-rmse:5.00457
# [937]	validation-rmse:5.00463
# [938]	validation-rmse:5.00455
# [939]	validation-rmse:5.00450
# [940]	validation-rmse:5.00440
# [941]	validation-rmse:5.00439
# [942]	validation-rmse:5.00435
# [943]	validation-rmse:5.00438
# [944]	validation-rmse:5.00437
# [945]	validation-rmse:5.00428
# [946]	validation-rmse:5.00443
# [947]	validation-rmse:5.00457
# [948]	validation-rmse:5.00467
# [949]	validation-rmse:5.00464
# [950]	validation-rmse:5.00467
# [951]	validation-rmse:5.00459
# [952]	validation-rmse:5.00454
# [953]	validation-rmse:5.00455
# [954]	validation-rmse:5.00448
# [955]	validation-rmse:5.00445
# [956]	validation-rmse:5.00448
# [957]	validation-rmse:5.00422
# [958]	validation-rmse:5.00409
# [959]	validation-rmse:5.00390
# [960]	validation-rmse:5.00388
# [961]	validation-rmse:5.00381
# [962]	validation-rmse:5.00377
# [963]	validation-rmse:5.00346
# [964]	validation-rmse:5.00341
# [965]	validation-rmse:5.00344
# [966]	validation-rmse:5.00346
# [967]	validation-rmse:5.00349
# [968]	validation-rmse:5.00340
# [969]	validation-rmse:5.00335
# [970]	validation-rmse:5.00330
# [971]	validation-rmse:5.00326
# [972]	validation-rmse:5.00313
# [973]	validation-rmse:5.00319
# [974]	validation-rmse:5.00305
# [975]	validation-rmse:5.00305
# [976]	validation-rmse:5.00307
# [977]	validation-rmse:5.00298
# [978]	validation-rmse:5.00294
# [979]	validation-rmse:5.00284
# [980]	validation-rmse:5.00281
# [981]	validation-rmse:5.00279
# [982]	validation-rmse:5.00278
# [983]	validation-rmse:5.00277
# [984]	validation-rmse:5.00293
# [985]	validation-rmse:5.00296
# [986]	validation-rmse:5.00299
# [987]	validation-rmse:5.00301
# [988]	validation-rmse:5.00314
# [989]	validation-rmse:5.00311
# [990]	validation-rmse:5.00305
# [991]	validation-rmse:5.00315
# [992]	validation-rmse:5.00306
# [993]	validation-rmse:5.00308
# [994]	validation-rmse:5.00306
# [995]	validation-rmse:5.00303
# [996]	validation-rmse:5.00319
# [997]	validation-rmse:5.00321
# [998]	validation-rmse:5.00296
# [999]	validation-rmse:5.00295
# 2024/05/22 12:53:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/xgboost/core.py:160: UserWarning: [12:53:05] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_b6b50u1t0e/croot/xgboost-split_1713972723244/work/cpp_src/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# /opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/xgboost/core.py:160: UserWarning: [12:53:06] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_b6b50u1t0e/croot/xgboost-split_1713972723244/work/cpp_src/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# Instead of autolog we can also log the model using `log_model`, before doing that we need to disable the global setting for autolog:
# `mlflow.xgboost.autolog(disable=True)`
# ## Log model
# we add a line to our `with mlflow.start_run()` block:
#
# ```python
# mlflow.<framework>.log_model(model, artifact_path="models_mlflow")
# ```
#
# where `<framework>` could be `sklearn`, `xgboost`...etc.
# The `artifact_path` defines where in the `artifact_uri` the model is stored.
#
# This will save our model inside `models_mlflow` directory in the experiment folder. (Using Autologging would store more data on parameters as well as the model. i.e: This is redundant when using the autologger).
#
# ## Log other artifacts
# Sometimes we may want to save some artifacts, e.g. `DictVectorizer` object, for inference. In that case we save the artifact as:
# ```
#     prep_path = "models/preprocessor.b"
#     os.makedirs(os.path.dirname(prep_path), exist_ok=True)
#     with open(prep_path, 'wb') as file:
#         pickle.dump(dv, file)
#     mlflow.log_artifact(prep_path, artifact_path = "preprocessor")
# ```

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    params = {
        "learning_rate":0.05962727037069885,
        "max_depth":8,
        "min_child_weight": 1.6262090424037392,
        "objective": "reg:linear",
        "reg_alpha": 0.21113459659178727,
        "reg_lambda": 0.24977063291390747,
        "seed": 42}
    
    train = xgb.DMatrix(x_train, label=y_train)
    valid = xgb.DMatrix(x_val, label=y_val)
    
    mlflow.log_params(params)
    
    booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=1000,
                evals=[(valid,"validation")],
                early_stopping_rounds=50
            )
    mlflow.log_metric("rmse", rmse)
    
    # log the preprocessor
    prep_path = "models/preprocessor.b"
    os.makedirs(os.path.dirname(prep_path), exist_ok=True)
    with open(prep_path, 'wb') as file:
        pickle.dump(dv, file)
    mlflow.log_artifact(prep_path, artifact_path = "preprocessor")
    
    mlflow.xgboost.log_model(booster, artifact_path = "models_mlflow")

# %% [markdown]
# # Retrieve model
#
# To find the prediction code:
# "experiment_name > Artifacts > models_mlflow > Make Predictions"
#
# What to evaluate which model is good for production:
# * Duration: How long is the training time?
# * Metrics: Which one achieved the lowest error?
# * Model size:

# %%
logged_model = 'runs:/904f34a4b7c54aefa27e589d795c8277/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
# method 1: pass in as a python function
loaded_model

# %%
# method 2: pass in as a xgboost model
xgboost = mlflow.xgboost.load_model(logged_model)
xgboost

# %%
y_pred = xgboost.predict(valid)

# %%
y_pred[:10]

# %% [markdown]
# # Save both model and the dv

# %%
import mlflow.sklearn
from sklearn.pipeline import make_pipeline

# %%
train_dicts = df_train[categorical+numerical].to_dict(orient="records")
with mlflow.start_run():
    mlflow.log_param("train-data-path", "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-01.parquet")
    mlflow.log_param("val-data-path", "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-02.parquet")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    
    dv = DictVectorizer()
    x_train = dv.fit_transform(train_dicts)

    lr = Lasso(alpha=alpha)
    lr.fit(x_train,y_train)
    
    # 1. save preprocessor
    prep_path = "models/preprocessor.b"
    os.makedirs(os.path.dirname(prep_path), exist_ok=True)
    with open(prep_path, 'wb') as file:
        pickle.dump(dv, file)
    mlflow.log_artifact(prep_path, artifact_path = "preprocessor")

    # 2. save model
    mlflow.sklearn.log_model(lr, artifact_path="models_pickle") 
    # mlflow.log_artifact will not create the snippet code
    
    y_pred = lr.predict(val_dicts)
    rmse = mean_squared_error(y_val,y_pred,squared=False) 
    mlflow.log_metric("rmse",rmse)
    mlflow.end_run()
# Out:
# /opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Alternative, save as a pipeline
train_dicts = df_train[categorical+numerical].to_dict(orient="records")
with mlflow.start_run():
    mlflow.log_param("train-data-path", "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-01.parquet")
    mlflow.log_param("val-data-path", "/Users/yihanzhou/PycharmProjects/mlops-zoomcamp/data/green_tripdata_2024-02.parquet")
    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    
    pipepline = make_pipeline(
        DictVectorizer(),
        Lasso(alpha=alpha)
    )
    pipepline.fit(train_dicts, y_train)
    
    y_pred = pipepline.predict(val_dicts)
    
    rmse = mean_squared_error(y_val,y_pred,squared=False) 
    mlflow.log_metric("rmse",rmse)
    
    # save pipeline
    mlflow.sklearn.log_model(pipepline, artifact_path="models_pickle") 
    mlflow.end_run()
# Out:
# /opt/anaconda3/envs/mlopszoomcamp/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # Load both model and the dv

# %%
from mlflow.tracking import MlflowClient
MLFLOW_TRACKING_URI = "http://127.0.0.1:5005/"
RUN_ID= '6866dfdb9a044eee85683af944fb732b'

# 1. Load the preprocessor
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
prep_path = client.download_artifacts(run_id=RUN_ID, path='preprocessor/preprocessor.b')
with open(prep_path, 'rb') as f_out:
    dv = pickle.load(f_out)
    
# 2. Load the model
logged_model = F'runs:/{RUN_ID}/models_pickle'
model = mlflow.pyfunc.load_model(logged_model)

# %% [markdown]
# # Load pipeline

# %%
from mlflow.tracking import MlflowClient
MLFLOW_TRACKING_URI = "http://127.0.0.1:5005/"
RUN_ID= 'bca046633ac94a0dacad64f65d5901fb'

logged_model = F'runs:/{RUN_ID}/models_pickle'
model = mlflow.pyfunc.load_model(logged_model)
